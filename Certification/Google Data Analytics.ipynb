# %% [markdown]
# # COURSERA - GOOGLE DATA ANALYTICS CERTIFICATE

# %% [markdown]
# - This certificate, provided by Coursera, requires learners to complete 8 courses below. Each course is presented with an image of certification and a link to it's verification.

# %% [markdown]
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## Course 01 - Foundations: Data, Data, Everywhere

# %% [markdown]
# https://coursera.org/verify/KHTLTXY2ZYUM

# %% [markdown]
# ![Course%2001%20-%20Foundations,%20Data,%20Data,%20Everywhere-1.jpg](attachment:Course%2001%20-%20Foundations,%20Data,%20Data,%20Everywhere-1.jpg)

# %% [markdown]
# ## Course 02 - Ask Questions to Make Data-Driven Decisions

# %% [markdown]
# https://coursera.org/verify/SY7LBKVFJZDX

# %% [markdown]
# ![Course%2002%20-%20Ask%20Questions%20to%20Make%20Data-Driven%20Decisions-1.jpg](attachment:Course%2002%20-%20Ask%20Questions%20to%20Make%20Data-Driven%20Decisions-1.jpg)

# %% [markdown]
# ## Course 03 - Prepare Data for Exploration

# %% [markdown]
# https://coursera.org/verify/S5D8URL4NZQ6

# %% [markdown]
# ![Course%2003%20-%20Prepare%20Data%20for%20Exploration-1.jpg](attachment:Course%2003%20-%20Prepare%20Data%20for%20Exploration-1.jpg)

# %% [markdown]
# ## Course 04 - Process Data from Dirty to Clean

# %% [markdown]
# ## Course 05 - Analyze Data to Answer Questions

# %% [markdown]
# ## Course 06 - Share Data Through the Art of Visualization

# %% [markdown]
# ## Course 07 - Data Analysis with R Programming

# %% [markdown]
# ## Course 08 - Google Data Analytics Capstone: Complete a Case Study

# %% [markdown]
# ----------------------------------------------------------------------------------------

# %% [markdown]
# # The End
